# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenzo-KBI/suniy-intelekt-mustaqil-ish/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
from gtts import gTTS
from IPython.display import Audio










import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
from gtts import gTTS
from IPython.display import Audio

print("=== 1-BO'LIM: PANDAS BILAN ISHLASH ===")
# Shaxsiy kompyuter va uning atrofidagi jihozlar jadvali
texnika_baza = {
    "Jihoz nomi": ["Notbuk RTX 3050", "Sichqoncha", "Klaviatura", "Borofone Naushnik", "Kalonka"],
    "Brendi": ["Asus", "Logitech", "HP", "Borofone", "JBL"],
    "Narxi ($)": [850, 25, 40, 35, 120],
    "Kafolati (oy)": [12, 6, 12, 3, 6]
}

baza_df = pd.DataFrame(texnika_baza)
print("\nMening do'konimdagi jihozlar jadvali:")
print(baza_df)

print("\nFiltr: Narxi 50$ dan baland bo'lgan qimmat jihozlar:")
qimmat_filtr = baza_df[baza_df["Narxi ($)"] > 50]
print(qimmat_filtr)


print("\n=== 2-BO'LIM: MATPLOTLIB BILAN ITALIYA BAYROG'INI CHIZISH ===")
plt.figure(figsize=(6, 4))

# Italiya bayrog'i: Yashil, Oq, Qizil
plt.axvspan(0, 1, color='#009246')
plt.axvspan(1, 2, color='#FFFFFF')
plt.axvspan(2, 3, color='#CE2B37')

plt.xlim(0, 3)
plt.ylim(0, 2)
plt.axis('off')
plt.title("Matplotlib kutubxonasida chizilgan Italiya bayrog'i")
plt.show()


print("\n=== 3-BO'LIM: OPENCV YORDAMIDA STRUKTURALI SHAKL TAYYORLASH ===")
tasvir_matritsa = np.zeros((300, 300, 3), dtype=np.uint8)
cv2.circle(tasvir_matritsa, (150, 150), 80, (0, 255, 255), -1)
cv2.rectangle(tasvir_matritsa, (50, 50), (250, 250), (255, 0, 0), 3)

# Tasvirni xiralashtirish (Gaussian Blur)
xiralashgan_tasvir = cv2.GaussianBlur(tasvir_matritsa, (15, 15), 0)

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(cv2.cvtColor(tasvir_matritsa, cv2.COLOR_BGR2RGB))
ax[0].set_title("Asliy Geometrik Tasvir")
ax[0].axis('off')

ax[1].imshow(cv2.cvtColor(xiralashgan_tasvir, cv2.COLOR_BGR2RGB))
ax[1].set_title("OpenCV orqali xiralashtirilgan tasvir")
ax[1].axis('off')
plt.show()


print("\n=== 4-BO'LIM: GTTS ORQALI MATNNI NUTKKA AYLANTIRISH ===")
inglizcha_matn = "Hello! I am a student. This is my individual practical work for Artificial Intelligence class."
ovoz_fayli = gTTS(text=inglizcha_matn, lang='en', slow=False)
ovoz_fayli.save("shaxsiy_amaliyot_ovozi.mp3")
print("Ovoz muvaffaqiyatli saqlandi!")

Audio("shaxsiy_amaliyot_ovozi.mp3")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.4.1
#     Uninstalling click-8.4.1:
#       Successfully uninstalled click-8.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 1.17.0 requires click>=8.4.0, but you have click 8.1.8 which is incompatible.
# typer 0.25.1 requires click>=8.2.1, but you have click 8.1.8 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# ...
# === 1-BO'LIM: PANDAS BILAN ISHLASH ===
#
# Mening do'konimdagi jihozlar jadvali:
#           Jihoz nomi    Brendi  Narxi ($)  Kafolati (oy)
# 0    Notbuk RTX 3050      Asus        850             12
# 1         Sichqoncha  Logitech         25              6
# 2         Klaviatura        HP         40             12
# ...
